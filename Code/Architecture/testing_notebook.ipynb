# %%
from models.tacotron2 import Tacotron2Wave
import torch
import torchaudio

# %%
import tensorflow as tf

if tf.config.experimental.list_physical_devices('GPU'):
    print("TensorFlow will run on GPU.")
    gpus = []#tf.config.experimental.list_physical_devices('GPU')
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
else:
    print("TensorFlow will run on CPU.")
# Out:
# TensorFlow will run on CPU.

# %%
input_text = "أنا اسمي فريدة"

# %%
! pip install farasapy
# Out:
# Collecting farasapy
#   Downloading farasapy-0.0.14-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: requests in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from farasapy) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from farasapy) (4.66.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from requests->farasapy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from requests->farasapy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from requests->farasapy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from requests->farasapy) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from tqdm->farasapy) (0.4.6)
# Downloading farasapy-0.0.14-py3-none-any.whl (11 kB)
# Installing collected packages: farasapy
# Successfully installed farasapy-0.0.14

# %%
! pip install pandas numpy
# Out:
# Requirement already satisfied: pandas in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
from farasa.diacratizer import FarasaDiacritizer

diacritizer = FarasaDiacritizer()
# Diacritize the input text
diacritized_text = diacritizer.diacritize(input_text)
print(diacritized_text)
# Out:
# أَنا اسْمي فَريدَةٌ

# %%
pip install camel-tools
# Out:
# Collecting camel-tools
#   Downloading camel_tools-1.2.0.tar.gz (58 kB)
#      ---------------------------------------- 0.0/58.1 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/58.1 kB ? eta -:--:--
#      -------------------- ----------------- 30.7/58.1 kB 330.3 kB/s eta 0:00:01
#      --------------------------------- ---- 51.2/58.1 kB 375.8 kB/s eta 0:00:01
#      -------------------------------------- 58.1/58.1 kB 382.9 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting future (from camel-tools)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: six in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from camel-tools) (1.16.0)
# Collecting docopt (from camel-tools)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: cachetools in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from camel-tools) (5.3.3)
# Requirement already satisfied: numpy in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from camel-tools) (1.26.4)
# Requirement already satisfied: scipy in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from camel-tools) (1.12.0)
# Requirement already satisfied: pandas in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from camel-tools) (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from camel-tools) (1.4.1.post1)
# Collecting dill (from camel-tools)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=1.3 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from camel-tools) (2.3.0)
# Collecting transformers>=3.0.2 (from camel-tools)
#   Downloading transformers-4.41.0-py3-none-any.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.8 kB ? eta -:--:--
#      ---------------------------------------- 43.8/43.8 kB 1.1 MB/s eta 0:00:00
# Collecting editdistance (from camel-tools)
#   Downloading editdistance-0.8.1-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: requests in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from camel-tools) (2.31.0)
# Requirement already satisfied: filelock in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.3->camel-tools) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.3->camel-tools) (4.10.0)
# Requirement already satisfied: sympy in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.3->camel-tools) (1.12)
# Requirement already satisfied: networkx in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.3->camel-tools) (3.3)
# Requirement already satisfied: jinja2 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.3->camel-tools) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.3->camel-tools) (2024.5.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.3->camel-tools) (2021.4.0)
# Collecting huggingface-hub<1.0,>=0.23.0 (from transformers>=3.0.2->camel-tools)
#   Downloading huggingface_hub-0.23.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from transformers>=3.0.2->camel-tools) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from transformers>=3.0.2->camel-tools) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers>=3.0.2->camel-tools)
#   Downloading regex-2024.5.15-cp312-cp312-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ---------------------------------------- 42.0/42.0 kB 2.1 MB/s eta 0:00:00
# Collecting tokenizers<0.20,>=0.19 (from transformers>=3.0.2->camel-tools)
#   Downloading tokenizers-0.19.1-cp312-none-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.1 (from transformers>=3.0.2->camel-tools)
#   Downloading safetensors-0.4.3-cp312-none-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from transformers>=3.0.2->camel-tools) (4.66.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from pandas->camel-tools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from pandas->camel-tools) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from pandas->camel-tools) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from requests->camel-tools) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from requests->camel-tools) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from requests->camel-tools) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from requests->camel-tools) (2024.2.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->camel-tools) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn->camel-tools) (3.3.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.3->camel-tools) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.3->camel-tools) (2021.12.0)
# Requirement already satisfied: colorama in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers>=3.0.2->camel-tools) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=1.3->camel-tools) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from sympy->torch>=1.3->camel-tools) (1.3.0)
# Downloading transformers-4.41.0-py3-none-any.whl (9.1 MB)
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.1 MB ? eta -:--:--
#     --------------------------------------- 0.2/9.1 MB 2.1 MB/s eta 0:00:05
#     --------------------------------------- 0.2/9.1 MB 2.0 MB/s eta 0:00:05
#    - -------------------------------------- 0.3/9.1 MB 1.9 MB/s eta 0:00:05
#    -- ------------------------------------- 0.5/9.1 MB 2.2 MB/s eta 0:00:05
#    -- ------------------------------------- 0.6/9.1 MB 2.4 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/9.1 MB 2.5 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/9.1 MB 2.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.1/9.1 MB 2.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.3/9.1 MB 2.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.5/9.1 MB 3.0 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.1 MB 2.8 MB/s eta 0:00:03
#    ------- -------------------------------- 1.6/9.1 MB 2.8 MB/s eta 0:00:03
#    ------- -------------------------------- 1.7/9.1 MB 2.8 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/9.1 MB 2.6 MB/s eta 0:00:03
#    -------- ------------------------------- 1.9/9.1 MB 2.6 MB/s eta 0:00:03
#    --------- ------------------------------ 2.1/9.1 MB 2.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.3/9.1 MB 2.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.5/9.1 MB 2.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.6/9.1 MB 2.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.7/9.1 MB 2.8 MB/s eta 0:00:03
#    ------------ --------------------------- 2.9/9.1 MB 2.9 MB/s eta 0:00:03
#    ------------- -------------------------- 3.1/9.1 MB 2.9 MB/s eta 0:00:03
#    -------------- ------------------------- 3.3/9.1 MB 3.0 MB/s eta 0:00:02
#    --------------- ------------------------ 3.6/9.1 MB 3.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.8/9.1 MB 3.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.0/9.1 MB 3.2 MB/s eta 0:00:02
#    ------------------ --------------------- 4.1/9.1 MB 3.2 MB/s eta 0:00:02
#    ------------------- -------------------- 4.4/9.1 MB 3.3 MB/s eta 0:00:02
#    -------------------- ------------------- 4.6/9.1 MB 3.3 MB/s eta 0:00:02
#    --------------------- ------------------ 4.8/9.1 MB 3.3 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.0/9.1 MB 3.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.2/9.1 MB 3.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.4/9.1 MB 3.5 MB/s eta 0:00:02
#    ------------------------ --------------- 5.6/9.1 MB 3.5 MB/s eta 0:00:01
#    ------------------------- -------------- 5.8/9.1 MB 3.5 MB/s eta 0:00:01
#    -------------------------- ------------- 6.0/9.1 MB 3.5 MB/s eta 0:00:01
#    --------------------------- ------------ 6.1/9.1 MB 3.5 MB/s eta 0:00:01
#    --------------------------- ------------ 6.3/9.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.5/9.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.6/9.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.6/9.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.6/9.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.6/9.1 MB 3.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.7/9.1 MB 3.2 MB/s eta 0:00:01
#    ------------------------------- -------- 7.1/9.1 MB 3.3 MB/s eta 0:00:01
#    ------------------------------- -------- 7.2/9.1 MB 3.4 MB/s eta 0:00:01
#    ------------------------------- -------- 7.2/9.1 MB 3.4 MB/s eta 0:00:01
#    ------------------------------- -------- 7.2/9.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.7/9.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.7/9.1 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------- -- 8.5/9.1 MB 3.6 MB/s eta 0:00:01
#    -------------------------------------- - 8.7/9.1 MB 3.5 MB/s eta 0:00:01
#    -------------------------------------- - 8.7/9.1 MB 3.5 MB/s eta 0:00:01
#    -------------------------------------- - 8.7/9.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  9.1/9.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.1/9.1 MB 3.5 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ---------------------------------------- 0.0/116.3 kB ? eta -:--:--
#    ---------------------------------------- 116.3/116.3 kB 3.4 MB/s eta 0:00:00
# Downloading editdistance-0.8.1-cp312-cp312-win_amd64.whl (79 kB)
#    ---------------------------------------- 0.0/79.9 kB ? eta -:--:--
#    ---------------------------------------- 79.9/79.9 kB 2.2 MB/s eta 0:00:00
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ---------------------------------------- 0.0/491.3 kB ? eta -:--:--
#    --------------- ------------------------ 194.6/491.3 kB 5.9 MB/s eta 0:00:01
#    ------------------------------ --------- 368.6/491.3 kB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  481.3/491.3 kB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 491.3/491.3 kB 3.4 MB/s eta 0:00:00
# Downloading huggingface_hub-0.23.0-py3-none-any.whl (401 kB)
#    ---------------------------------------- 0.0/401.2 kB ? eta -:--:--
#    ------------------- -------------------- 194.6/401.2 kB 3.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 348.2/401.2 kB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 401.2/401.2 kB 3.1 MB/s eta 0:00:00
# Downloading regex-2024.5.15-cp312-cp312-win_amd64.whl (268 kB)
#    ---------------------------------------- 0.0/268.5 kB ? eta -:--:--
#    ------------------------- -------------- 174.1/268.5 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 268.5/268.5 kB 3.3 MB/s eta 0:00:00
# Downloading safetensors-0.4.3-cp312-none-win_amd64.whl (289 kB)
#    ---------------------------------------- 0.0/289.4 kB ? eta -:--:--
#    ------------------------- -------------- 184.3/289.4 kB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 289.4/289.4 kB 3.6 MB/s eta 0:00:00
# Downloading tokenizers-0.19.1-cp312-none-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/2.2 MB 3.6 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.3/2.2 MB 3.7 MB/s eta 0:00:01
#    ------ --------------------------------- 0.3/2.2 MB 3.5 MB/s eta 0:00:01
#    ------- -------------------------------- 0.4/2.2 MB 2.3 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.2 MB 3.7 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.2 MB 3.7 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.2 MB 3.6 MB/s eta 0:00:01
#    ------------------------ --------------- 1.4/2.2 MB 3.7 MB/s eta 0:00:01
#    --------------------------- ------------ 1.5/2.2 MB 3.7 MB/s eta 0:00:01
#    ------------------------------ --------- 1.7/2.2 MB 3.7 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------ --- 2.0/2.2 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 3.5 MB/s eta 0:00:00
# Building wheels for collected packages: camel-tools, docopt
#   Building wheel for camel-tools (setup.py): started
#   Building wheel for camel-tools (setup.py): finished with status 'done'
#   Created wheel for camel-tools: filename=camel_tools-1.2.0-py3-none-any.whl size=99065 sha256=79b00e126357e8e08ebe165e28c00ae3debe138cfbb48ab454d8638ba45d446b
#   Stored in directory: c:\users\farid\appdata\local\pip\cache\wheels\f2\6a\e8\767b8bf672a6dedec33dec0ee53e9ef3ce935e1e864ca45530
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13774 sha256=4ab0fb7b4185848d212348514f50215579a06819142e53979849fdfc1b392c3b
#   Stored in directory: c:\users\farid\appdata\local\pip\cache\wheels\1a\bf\a1\4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built camel-tools docopt
# Installing collected packages: docopt, safetensors, regex, future, editdistance, dill, huggingface-hub, tokenizers, transformers, camel-tools
# Successfully installed camel-tools-1.2.0 dill-0.3.8 docopt-0.6.2 editdistance-0.8.1 future-1.0.0 huggingface-hub-0.23.0 regex-2024.5.15 safetensors-0.4.3 tokenizers-0.19.1 transformers-4.41.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
from camel_tools.utils.charmap import CharMapper

# Set the environment variable for camel-tools
os.environ['CAMELTOOLS_DATA'] = r'C:\UNI\Term 8\Deep Learning\Arabic TTS\camel_tools-master'  # Using raw string for Windows path

# %%
# Function to apply CharMapper to a sentence, handling NaN values
def map_sentence(sentence):
    if pd.isna(sentence):
        return ""
    else:
        ar2bw = CharMapper.builtin_mapper('ar2bw')
        return ar2bw(sentence)

# %%
buckwalter_text = map_sentence(diacritized_text)
print(buckwalter_text)
# Out:
# >anA Asomy farydapN

# %%
import subprocess

# Call inferencetest.py using subprocess
subprocess.run(['python', 'inferencetest.py', '--input_text', buckwalter_text])
# Out:
# CompletedProcess(args=['python', 'inf2.py', '--input_text', '>anA Asomy farydapN'], returncode=0)

# %%
from IPython.display import Audio

# Define the path to the output audio file
output_audio_path = "output_audio2.wav"

# Play the audio directly in the notebook
Audio(output_audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.9.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.51.0-cp312-cp312-win_amd64.whl.metadata (162 kB)
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.8 kB ? eta -:--:--
#      ------------- ----------------------- 61.4/162.8 kB 812.7 kB/s eta 0:00:01
#      ---------------------------- --------- 122.9/162.8 kB 1.0 MB/s eta 0:00:01
#      -------------------------------------- 162.8/162.8 kB 1.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\farid\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.9.0-cp312-cp312-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#     --------------------------------------- 0.2/8.0 MB 4.6 MB/s eta 0:00:02
#    - -------------------------------------- 0.4/8.0 MB 3.9 MB/s eta 0:00:02
#    -- ------------------------------------- 0.5/8.0 MB 3.8 MB/s eta 0:00:02
#    --- ------------------------------------ 0.7/8.0 MB 4.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.9/8.0 MB 3.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/8.0 MB 4.0 MB/s eta 0:00:02
#    ------ --------------------------------- 1.3/8.0 MB 4.0 MB/s eta 0:00:02
#    ------- -------------------------------- 1.4/8.0 MB 4.0 MB/s eta 0:00:02
#    -------- ------------------------------- 1.6/8.0 MB 4.0 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/8.0 MB 4.0 MB/s eta 0:00:02
#    --------- ------------------------------ 2.0/8.0 MB 3.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.2/8.0 MB 3.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.4/8.0 MB 4.0 MB/s eta 0:00:02
#    ------------ --------------------------- 2.5/8.0 MB 4.0 MB/s eta 0:00:02
#    ------------- -------------------------- 2.7/8.0 MB 3.9 MB/s eta 0:00:02
#    -------------- ------------------------- 2.9/8.0 MB 4.0 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.0 MB 3.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.3/8.0 MB 3.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.5/8.0 MB 3.9 MB/s eta 0:00:02
#    ------------------ --------------------- 3.6/8.0 MB 3.9 MB/s eta 0:00:02
#    ------------------- -------------------- 3.8/8.0 MB 3.9 MB/s eta 0:00:02
#    ------------------- -------------------- 4.0/8.0 MB 3.9 MB/s eta 0:00:02
#    -------------------- ------------------- 4.1/8.0 MB 3.8 MB/s eta 0:00:02
#    --------------------- ------------------ 4.3/8.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.0 MB 3.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.0 MB 3.9 MB/s eta 0:00:01
#    ------------------------ --------------- 4.9/8.0 MB 3.9 MB/s eta 0:00:01
#    ------------------------- -------------- 5.0/8.0 MB 3.9 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 3.9 MB/s eta 0:00:01
#    --------------------------- ------------ 5.4/8.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.6/8.0 MB 3.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.8/8.0 MB 3.9 MB/s eta 0:00:01
#    ------------------------------ --------- 6.0/8.0 MB 3.9 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.0 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.0 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 6.5/8.0 MB 3.9 MB/s eta 0:00:01
#    --------------------------------- ------ 6.7/8.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.9/8.0 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.0/8.0 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 7.2/8.0 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 7.4/8.0 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 7.6/8.0 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 7.7/8.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.0 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 3.8 MB/s eta 0:00:00
# Downloading contourpy-1.2.1-cp312-cp312-win_amd64.whl (189 kB)
#    ---------------------------------------- 0.0/189.9 kB ? eta -:--:--
#    ------------------------------ --------- 143.4/189.9 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 189.9/189.9 kB 2.9 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.51.0-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/2.2 MB 4.2 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.3/2.2 MB 3.9 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.2 MB 3.9 MB/s eta 0:00:01
#    ------------ --------------------------- 0.7/2.2 MB 3.8 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.2 MB 3.5 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.2 MB 3.8 MB/s eta 0:00:01
#    --------------------- ------------------ 1.2/2.2 MB 3.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 3.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.5/2.2 MB 3.7 MB/s eta 0:00:01
#    ------------------------------- -------- 1.7/2.2 MB 3.7 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------- -- 2.0/2.2 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 3.6 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp312-cp312-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#    ---------------------------------------- 56.0/56.0 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.51.0 kiwisolver-1.4.5 matplotlib-3.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from models.tacotron2 import Tacotron2Wave

model = Tacotron2Wave('checkpoints/exp_tc2/states.pth')
# model = model.to(device=device)

wave, mel_spec = model.tts(diacritized_text, return_mel=True, denoise=0.005)

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 3.5))
ax1.imshow(mel_spec.cpu(), origin='lower', aspect='auto', cmap='jet')
ax1.set_xlabel('Frame')
ax1.set_ylabel('Mel band')
ax1.set_title("Mel spectrogram / Waveform (Tacotron2)")
ax2.plot(wave)
ax2.set_xlim(0, len(wave))
ax2.set_xlabel('Sample')
fig.tight_layout()

# %%
input_text2 = "أنا هروح الكلية دلوقتي"

# %%
diacritized_text2 = diacritizer.diacritize(input_text2)
print(diacritized_text2)
# Out:
# أَنا هروحْ الكُلّيَّةِ دِلْوَقْتي

# %%
buckwalter_text2 = map_sentence(diacritized_text2)
print(buckwalter_text2)
# Out:
# >anA hrwHo Alkul~y~api dilowaqoty

# %%
# Call inferencetest.py using subprocess
subprocess.run(['python', 'inferencetest.py', '--input_text', buckwalter_text2])
# Out:
# CompletedProcess(args=['python', 'inferencetest.py', '--input_text', '>anA hrwHo Alkul~y~api dilowaqoty'], returncode=0)

# %%
from IPython.display import Audio

# Define the path to the output audio file
output_audio_path2 = "output_audio3.wav"

# Play the audio directly in the notebook
Audio(output_audio_path2)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
